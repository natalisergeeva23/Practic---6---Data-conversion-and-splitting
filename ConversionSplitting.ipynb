# %% [markdown]
# Цель: Преобразовать признаки и разбить датасет на обучающую и тестовую выборку.

# %% [markdown]
# Для начала как всегда добавляем библиотеки и считываем данные с файла.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weatherAUS_clear.csv')
df
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall
# 0                0  2008-12-01   Albury     13.4     22.9       0.6  \
# 1                1  2008-12-02   Albury      7.4     25.1       0.0
# 2                2  2008-12-03   Albury     12.9     25.7       0.0
# 3                3  2008-12-04   Albury      9.2     28.0       0.0
# 4                4  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 140782      145454  2017-06-20    Uluru      3.5     21.8       0.0
# 140783      145455  2017-06-21    Uluru      2.8     23.4       0.0
# 140784      145456  2017-06-22    Uluru      3.6     25.3       0.0
# 140785      145457  2017-06-23    Uluru      5.4     26.9       0.0
# 140786      145458  2017-06-24    Uluru      7.8     27.0       0.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am
# 0                W           44.0          W        WNW          20.0  \
# ...

# %% [markdown]
# Для удобства удаляем ненужные стобцы.

# %%
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='Date')
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 0        Albury     13.4     22.9       0.6           W           44.0  \
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 140782    Uluru      3.5     21.8       0.0           E           31.0
# 140783    Uluru      2.8     23.4       0.0           E           31.0
# 140784    Uluru      3.6     25.3       0.0         NNW           22.0
# 140785    Uluru      5.4     26.9       0.0           N           37.0
# 140786    Uluru      7.8     27.0       0.0          SE           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %% [markdown]
# Продемонстрировать работу OrdinalEncoder и использовать его на датасете:
# Подключаем специально для этого библиотеку с расширением OrdinalEncoder. Далее записывем в первую переменную координату. Указываем двумерный массив с указанием столбцов данных. Функция fit вычисляет формулировку для преобразования столбцов на основе стандартного масштабирования.

# %%
from sklearn.preprocessing import OrdinalEncoder

Oenc = OrdinalEncoder()
Oenc.fit(df[['Location','WindGustDir']])
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 0        Albury     13.4     22.9       0.6           W           44.0  \
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 140782    Uluru      3.5     21.8       0.0           E           31.0
# 140783    Uluru      2.8     23.4       0.0           E           31.0
# 140784    Uluru      3.6     25.3       0.0         NNW           22.0
# 140785    Uluru      5.4     26.9       0.0           N           37.0
# 140786    Uluru      7.8     27.0       0.0          SE           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %% [markdown]
# Вызовем функцию "categories" для определения значений в записанной переменной. Например, в первой строке столбца Location  стоит слово - Albury, по списку оно под 3 номером. Произведем кодирование.

# %%
Oenc.categories_
# Out:
# [array(['Adelaide', 'Albany', 'Albury', 'AliceSprings', 'BadgerysCreek',
#         'Ballarat', 'Bendigo', 'Brisbane', 'Cairns', 'Canberra', 'Cobar',
#         'CoffsHarbour', 'Dartmoor', 'Darwin', 'GoldCoast', 'Hobart',
#         'Katherine', 'Launceston', 'Melbourne', 'MelbourneAirport',
#         'Mildura', 'Moree', 'MountGambier', 'MountGinini', 'Newcastle',
#         'Nhil', 'NorahHead', 'NorfolkIsland', 'Nuriootpa', 'PearceRAAF',
#         'Penrith', 'Perth', 'PerthAirport', 'Portland', 'Richmond', 'Sale',
#         'SalmonGums', 'Sydney', 'SydneyAirport', 'Townsville',
#         'Tuggeranong', 'Uluru', 'WaggaWagga', 'Walpole', 'Watsonia',
#         'Williamtown', 'Witchcliffe', 'Wollongong', 'Woomera'],
#        dtype=object),
#  array(['E', 'ENE', 'ESE', 'N', 'NE', 'NNE', 'NNW', 'NW', 'S', 'SE', 'SSE',
#         'SSW', 'SW', 'Unknown', 'W', 'WNW', 'WSW'], dtype=object)]

# %% [markdown]
# Обратимся к столбцам датасета и через функцию fit_transform, заменим словосочетания на цифры. Исходя из этого результата можно понять, что все правильно и Albury находится под 3 номером, но тк счет идет с 0, переменная записалась под 2.

# %%
Oenc = OrdinalEncoder()
df[['Location','WindGustDir']] = Oenc.fit_transform(df[['Location','WindGustDir']])
df
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed
# 0            2.0     13.4     22.9       0.6         14.0           44.0  \
# 1            2.0      7.4     25.1       0.0         15.0           44.0
# 2            2.0     12.9     25.7       0.0         16.0           46.0
# 3            2.0      9.2     28.0       0.0          4.0           24.0
# 4            2.0     17.5     32.3       1.0         14.0           41.0
# ...          ...      ...      ...       ...          ...            ...
# 140782      41.0      3.5     21.8       0.0          0.0           31.0
# 140783      41.0      2.8     23.4       0.0          0.0           31.0
# 140784      41.0      3.6     25.3       0.0          6.0           22.0
# 140785      41.0      5.4     26.9       0.0          3.0           37.0
# 140786      41.0      7.8     27.0       0.0          9.0           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %% [markdown]
# Обязательно преобразовать 1 категориальный признак с помощью LabelEncoder.
# Подключаем библиотку LabelEncoder. Данное кодирование одинаково с предыдущем, но различие все же есть. Различие в том, что данное кодирование преобразует целевую переменную.

# %%
from sklearn.preprocessing import LabelEncoder
Lenc = LabelEncoder()
Lenc.fit(df['RainTomorrow'])
df['RainTomorrow'] = Lenc.fit_transform(df['RainTomorrow'])
df
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed
# 0            2.0     13.4     22.9       0.6         14.0           44.0  \
# 1            2.0      7.4     25.1       0.0         15.0           44.0
# 2            2.0     12.9     25.7       0.0         16.0           46.0
# 3            2.0      9.2     28.0       0.0          4.0           24.0
# 4            2.0     17.5     32.3       1.0         14.0           41.0
# ...          ...      ...      ...       ...          ...            ...
# 140782      41.0      3.5     21.8       0.0          0.0           31.0
# 140783      41.0      2.8     23.4       0.0          0.0           31.0
# 140784      41.0      3.6     25.3       0.0          6.0           22.0
# 140785      41.0      5.4     26.9       0.0          3.0           37.0
# 140786      41.0      7.8     27.0       0.0          9.0           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %% [markdown]
# Видно как закодировались переменные.

# %%
Lenc.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Провести нормализацию с помощью Normalize на числовых признаках.
# Подключаем библиотеку Normalizer.
# Принцип нормализации работает так - он вычитает минимальное значение из каждой записи, затем делит результат на разница между максимальным значением и минимальным значением.
# Передадим в переменную столбцы, которые будут нормализированы.

# %%
from sklearn.preprocessing import Normalizer

Norm = Normalizer()

df[['Pressure9am', 'Pressure3pm']] = Norm.fit_transform(df[['Pressure9am', 'Pressure3pm']])
df
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed
# 0            2.0     13.4     22.9       0.6         14.0           44.0  \
# 1            2.0      7.4     25.1       0.0         15.0           44.0
# 2            2.0     12.9     25.7       0.0         16.0           46.0
# 3            2.0      9.2     28.0       0.0          4.0           24.0
# 4            2.0     17.5     32.3       1.0         14.0           41.0
# ...          ...      ...      ...       ...          ...            ...
# 140782      41.0      3.5     21.8       0.0          0.0           31.0
# 140783      41.0      2.8     23.4       0.0          0.0           31.0
# 140784      41.0      3.6     25.3       0.0          6.0           22.0
# 140785      41.0      5.4     26.9       0.0          3.0           37.0
# 140786      41.0      7.8     27.0       0.0          9.0           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %% [markdown]
# Разделить датасет на обучающую и тестовую выборку.
# Подключаем библиотеку train_test_split.
# Y - столбец с обучающими данными, Х - столбец с тестовыми данными. Далле с помощью функции train_test_split разбиваем на выборки.
# random_state - параметр для управления перетасовкой,
# test_size - значение с плавающей точкой.
# Посмотрим что находится в каждой переменной.

# %%
from sklearn.model_selection import train_test_split

Y = df['RainTomorrow']
X = df.drop(columns=['RainTomorrow'])

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed
# 119008      31.0     13.5     26.0       0.0         12.0           33.0  \
# 68281       20.0     16.0     30.0       0.0          3.0           43.0
# 42953       47.0     19.0     26.3       0.0          4.0           41.0
# 91339       39.0     14.7     27.2       0.0          0.0           50.0
# 26428       34.0      5.7     15.5       0.0          2.0           11.0
# ...          ...      ...      ...       ...          ...            ...
# 110268      46.0     15.4     24.8       0.0         10.0           48.0
# 119879      36.0      3.2     15.5       9.2         11.0           43.0
# 103694      48.0     11.7     23.6       0.0          9.0           37.0
# 131932       3.0     20.2     34.5       0.0          9.0           37.0
# 121958      36.0     11.9     23.0       3.8         11.0           50.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %%
x_test
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed
# 117237      31.0     18.2     25.0       0.0          9.0       33.00000  \
# 31026       37.0      8.0     19.2       0.0          8.0       43.00000
# 103982      48.0     19.1     38.5       0.0          1.0       52.00000
# 25635       30.0      8.4     17.5       0.0          8.0       54.00000
# 105836       1.0      9.5     14.5       2.4         13.0       39.97052
# ...          ...      ...      ...       ...          ...            ...
# 16440       24.0      7.0     19.4       0.2         13.0       39.97052
# 87608       14.0     21.0     23.4       2.2         10.0       37.00000
# 37237       42.0     18.8     39.0       0.0         15.0       46.00000
# 96573       22.0     15.7     32.8       0.0          9.0       52.00000
# 8179        10.0      3.4     14.7       0.4         11.0       26.00000
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %%
y_train
# Out:
# 119008    0
# 68281     0
# 42953     0
# 91339     0
# 26428     0
#          ..
# 110268    0
# 119879    1
# 103694    0
# 131932    0
# 121958    1
# Name: RainTomorrow, Length: 112629, dtype: int32

# %%
y_test
# Out:
# 117237    0
# 31026     1
# 103982    0
# 25635     0
# 105836    0
#          ..
# 16440     1
# 87608     1
# 37237     0
# 96573     1
# 8179      0
# Name: RainTomorrow, Length: 28158, dtype: int32

# %%
print('Количестов входных обучающих данных', len(x_train))
print('Количестов проверочных обучающих данных', len(y_train))
print('Количестов входных тестовых данных', len(x_test))
print('Количестов проверочных тестовых данных', len(y_test))
# Out:
# Количестов входных обучающих данных 112629
# Количестов проверочных обучающих данных 112629
# Количестов входных тестовых данных 28158
# Количестов проверочных тестовых данных 28158

# %% [markdown]
# Вывод: В ходе данной практической работы, были преобрахованы признаки и разбит датасет на обучающую и тестовую выборку.
